# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright Pierian Data</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Forecast Evaluations

# %% [markdown]
# ### Classic Train/Test Split

# %%
import pandas as pd
from fbprophet import Prophet
# %matplotlib inline
# Out:
# ERROR:fbprophet:Importing plotly failed. Interactive plots will not work.

# %%
df = pd.read_csv('../Data/Miles_Traveled.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588 entries, 0 to 587
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DATE              588 non-null    object
#  1   TRFVOLUSM227NFWA  588 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 9.3+ KB

# %%
df.head()
# Out:
#          DATE  TRFVOLUSM227NFWA
# 0  1970-01-01           80173.0
# 1  1970-02-01           77442.0
# 2  1970-03-01           90223.0
# 3  1970-04-01           89956.0
# 4  1970-05-01           97972.0

# %%
df.columns = ['ds','y']

# %%
# YOU CAN SAFELY IGNORE THIS COPY WARNING
# CHECK THE DOCS LINK FOR MORE INFO ON THIS COPY WARNING
df['ds'] = pd.to_datetime(df['ds'])

# %%
df.head()
# Out:
#           ds        y
# 0 1970-01-01  80173.0
# 1 1970-02-01  77442.0
# 2 1970-03-01  90223.0
# 3 1970-04-01  89956.0
# 4 1970-05-01  97972.0

# %%
df.plot(x='ds',y='y',figsize=(18,6))

# %%
len(df)
# Out:
# 588

# %%
len(df) - 12
# Out:
# 576

# %%
train = df.iloc[:576]
test = df.iloc[576:]

# %%
m = Prophet()
m.fit(train)
future = m.make_future_dataframe(periods=12,freq='MS')
forecast = m.predict(future)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\JamesDuong\AppData\Local\Continuum\anaconda3\envs\DS\lib\site-packages\fbprophet\forecaster.py:400: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   (dates - pd.datetime(1970, 1, 1))

# %%
forecast.tail()
# Out:
#             ds          trend     yhat_lower     yhat_upper    trend_lower  \
# 583 2018-08-01  263219.378669  273514.667670  285682.023384  263201.859048
# 584 2018-09-01  263357.665883  256169.038734  267383.353175  263317.315758
# 585 2018-10-01  263491.492218  262866.883009  274498.025195  263429.600860
# 586 2018-11-01  263629.779432  249718.985895  261158.264592  263546.273158
# 587 2018-12-01  263763.605767  250896.027658  263000.834613  263657.321619
#
#        trend_upper  additive_terms  additive_terms_lower  \
# 583  263277.968726    16451.125033          16451.125033
# 584  263441.778089    -1666.545411          -1666.545411
# 585  263597.648676     5310.587893           5310.587893
# 586  263765.798975    -8203.436940          -8203.436940
# 587  263931.820017    -6916.514689          -6916.514689
#
#      additive_terms_upper        yearly  yearly_lower  yearly_upper  \
# 583          16451.125033  16451.125033  16451.125033  16451.125033
# 584          -1666.545411  -1666.545411  -1666.545411  -1666.545411
# 585           5310.587893   5310.587893   5310.587893   5310.587893
# 586          -8203.436940  -8203.436940  -8203.436940  -8203.436940
# 587          -6916.514689  -6916.514689  -6916.514689  -6916.514689
#
#      multiplicative_terms  multiplicative_terms_lower  \
# 583                   0.0                         0.0
# 584                   0.0                         0.0
# 585                   0.0                         0.0
# 586                   0.0                         0.0
# 587                   0.0                         0.0
#
#      multiplicative_terms_upper           yhat
# 583                         0.0  279670.503702
# 584                         0.0  261691.120472
# 585                         0.0  268802.080112
# 586                         0.0  255426.342492
# 587                         0.0  256847.091078

# %%
test.tail()
# Out:
#             ds         y
# 583 2018-08-01  286608.0
# 584 2018-09-01  260595.0
# 585 2018-10-01  282174.0
# 586 2018-11-01  258590.0
# 587 2018-12-01  268413.0

# %% [markdown]
# [Info on ax= parameter](https://stackoverflow.com/questions/13872533/plot-different-dataframes-in-the-same-figure)

# %%
ax = forecast.plot(x='ds',y='yhat',label='Predictions',legend=True,figsize=(12,8))

test.plot(x='ds',y='y',label='True Miles',legend=True,ax=ax,xlim=('2018-01-01','2019-01-01'))

# %%
from statsmodels.tools.eval_measures import rmse

# %%
predictions = forecast.iloc[-12:]['yhat']

# %%
predictions
# Out:
# 576    243683.663737
# 577    235311.776917
# 578    262511.200772
# 579    262708.863987
# 580    272429.495856
# 581    272679.913346
# 582    279136.474721
# 583    279670.503702
# 584    261691.120472
# 585    268802.080112
# 586    255426.342492
# 587    256847.091078
# Name: yhat, dtype: float64

# %%
test['y']
# Out:
# 576    245695.0
# 577    226660.0
# 578    268480.0
# 579    272475.0
# 580    286164.0
# 581    280877.0
# 582    288145.0
# 583    286608.0
# 584    260595.0
# 585    282174.0
# 586    258590.0
# 587    268413.0
# Name: y, dtype: float64

# %%
rmse(predictions,test['y'])
# Out:
# 8750.25052083061

# %%
test.mean()
# Out:
# y    268739.666667
# dtype: float64

# %% [markdown]
# # Prophet Diagnostics
#
# Prophet includes functionality for time series cross validation to measure forecast error using historical data. This is done by selecting cutoff points in the history, and for each of them fitting the model using data only up to that cutoff point. We can then compare the forecasted values to the actual values.

# %%
from fbprophet.diagnostics import cross_validation,performance_metrics
from fbprophet.plot import plot_cross_validation_metric

# %%
len(df)
# Out:
# 588

# %%
len(df)/12
# Out:
# 49.0

# %% [markdown]
# The initial period should be long enough to capture all of the components of the model, in particular seasonalities and extra regressors: at least a year for yearly seasonality, at least a week for weekly seasonality, etc.

# %%
# help(pd.Timedelta)

# %%
# Initial 5 years training period
initial = 5 * 365
initial = str(initial) + ' days'
# Fold every 5 years
period = 1 * 365
period = str(period) + ' days'
# Forecast 1 year into the future
horizon = 365
horizon = str(horizon) + ' days'

# %%
df_cv = cross_validation(m, initial=initial, period=period, horizon = horizon)
# Out:
# INFO:fbprophet:Making 42 forecasts with cutoffs between 1975-12-12 00:00:00 and 2016-12-01 00:00:00

# %%
df_cv.head()
# Out:
#           ds           yhat     yhat_lower     yhat_upper         y     cutoff
# 0 1976-01-01  102282.737593  100773.200342  103607.838429  102460.0 1975-12-12
# 1 1976-02-01   96811.141762   95361.609157   98193.280248   98528.0 1975-12-12
# 2 1976-03-01  112360.483572  110904.231870  113706.012275  114284.0 1975-12-12
# 3 1976-04-01  112029.016860  110579.854107  113436.279590  117014.0 1975-12-12
# 4 1976-05-01  119161.998161  117673.240715  120678.211302  123278.0 1975-12-12

# %%
df_cv[:20]
# Out:
#            ds           yhat     yhat_lower     yhat_upper         y  \
# 0  1976-01-01  102282.737593  100773.200342  103607.838429  102460.0
# 1  1976-02-01   96811.141762   95361.609157   98193.280248   98528.0
# 2  1976-03-01  112360.483572  110904.231870  113706.012275  114284.0
# 3  1976-04-01  112029.016860  110579.854107  113436.279590  117014.0
# 4  1976-05-01  119161.998161  117673.240715  120678.211302  123278.0
# 5  1976-06-01  121087.565354  119632.776248  122581.683348  124128.0
# 6  1976-07-01  126792.498038  125184.049257  128444.074261  130891.0
# 7  1976-08-01  129277.801054  127695.218876  131010.736246  131913.0
# 8  1976-09-01  116931.690752  115231.686555  118626.425934  119431.0
# 9  1976-10-01  118714.321278  117016.953726  120621.307943  121210.0
# 10 1976-11-01  110871.451304  108857.617759  112948.901669  112996.0
# 11 1976-12-01  108991.182209  106870.428113  111270.128688  113030.0
# 12 1977-01-01  108479.087389  107138.231922  109906.062316  102445.0
# 13 1977-02-01  102996.111525  101489.461098  104395.291124  102416.0
# 14 1977-03-01  118973.318113  117561.014040  120437.633076  119960.0
# 15 1977-04-01  120612.923709  119135.733695  122073.545047  121513.0
# 16 1977-05-01  127883.031830  126390.572186  129257.141825  128884.0
# 17 1977-06-01  129648.342256  128133.088147  131219.897476  129321.0
# 18 1977-07-01  136100.007184  134470.533796  137518.406106  136199.0
# 19 1977-08-01  137948.573539  136247.455074  139523.649493  136337.0
#
#        cutoff
# 0  1975-12-12
# 1  1975-12-12
# 2  1975-12-12
# 3  1975-12-12
# 4  1975-12-12
# 5  1975-12-12
# 6  1975-12-12
# 7  1975-12-12
# 8  1975-12-12
# 9  1975-12-12
# 10 1975-12-12
# 11 1975-12-12
# 12 1976-12-11
# 13 1976-12-11
# 14 1976-12-11
# 15 1976-12-11
# 16 1976-12-11
# 17 1976-12-11
# 18 1976-12-11
# 19 1976-12-11

# %%
df_cv.tail()
# Out:
#             ds           yhat     yhat_lower     yhat_upper         y  \
# 499 2017-08-01  273328.467970  267548.340195  279251.588850  283184.0
# 500 2017-09-01  255447.843997  249829.511553  261019.059893  262673.0
# 501 2017-10-01  262552.901413  256703.142773  268233.878544  278937.0
# 502 2017-11-01  249204.331440  243660.759957  254857.492395  257712.0
# 503 2017-12-01  250450.721819  244361.995574  255727.175554  266535.0
#
#         cutoff
# 499 2016-12-01
# 500 2016-12-01
# 501 2016-12-01
# 502 2016-12-01
# 503 2016-12-01

# %%
# Initial 5 years training period
initial = 5 * 365
initial = str(initial) + ' days'
# Fold every 5 years
period = 10 * 365
period = str(period) + ' days'
# Forecast 1 year into the future
horizon = 365
horizon = str(horizon) + ' days'

# %%
df_cv = cross_validation(m, initial=initial, period=period, horizon = horizon)
# Out:
# INFO:fbprophet:Making 5 forecasts with cutoffs between 1976-12-11 00:00:00 and 2016-12-01 00:00:00

# %%
df_cv
# Out:
#            ds           yhat     yhat_lower     yhat_upper         y  \
# 0  1977-01-01  108479.087389  107023.740830  109937.730000  102445.0
# 1  1977-02-01  102996.111525  101578.100101  104430.997615  102416.0
# 2  1977-03-01  118973.318113  117519.976532  120493.790311  119960.0
# 3  1977-04-01  120612.923709  119198.489830  122015.458649  121513.0
# 4  1977-05-01  127883.031830  126355.839265  129312.450187  128884.0
# 5  1977-06-01  129648.342256  128024.632850  131142.985362  129321.0
# 6  1977-07-01  136100.007184  134410.354347  137696.044812  136199.0
# 7  1977-08-01  137948.573539  136340.717834  139616.688441  136337.0
# 8  1977-09-01  125323.658391  123533.993108  127020.182540  124203.0
# 9  1977-10-01  127468.182192  125708.558356  129145.459079  127388.0
# 10 1977-11-01  119758.274632  117853.116505  121603.797168  118486.0
# 11 1977-12-01  119093.480711  117023.424888  121283.248434  116257.0
# 12 1987-01-01  141949.134462  138578.318172  145357.841338  139918.0
# 13 1987-02-01  136597.651985  133192.790840  139809.880099  135996.0
# 63  117 days  2.010623e+07  4483.996740  3341.901127  0.015758       0.7
# 75  118 days  2.133499e+07  4618.981764  3669.814813  0.017050       0.7
# 87  120 days  1.967055e+07  4435.148827  3327.928592  0.015744       0.7
# 99  121 days  4.166916e+07  6455.165095  4317.240942  0.019222       0.7
# 4   141 days  3.081409e+07  5551.044078  3370.089073  0.016079       0.8
# 16  142 days  3.438259e+07  5863.667285  3883.627983  0.019640       0.7
# 28  143 days  3.514306e+07  5928.158078  4005.862058  0.019933       0.6
# ..       ...           ...          ...          ...       ...       ...
# 80  271 days  3.987511e+07  6314.674121  4976.697924  0.023250       0.4
# 92  273 days  4.844885e+07  6960.520511  5553.268374  0.025891       0.4
# 104 274 days  5.344181e+07  7310.390781  6099.873093  0.027976       0.3
# 9   294 days  4.358237e+07  6601.694686  5107.910769  0.024477       0.4
# 21  295 days  4.833680e+07  6952.467359  5700.946543  0.028662       0.3
# 33  296 days  4.493632e+07  6703.455933  5371.935619  0.025776       0.4
# 45  298 days  4.346401e+07  6592.723880  5032.356394  0.023663       0.5
# 57  299 days  4.552935e+07  6747.544186  5373.830620  0.025112       0.4
# 69  300 days  4.552068e+07  6746.901166  5365.366312  0.025043       0.4
# 81  301 days  4.089633e+07  6395.023462  4890.486857  0.022897       0.5
# 93  303 days  2.522518e+07  5022.467234  3784.087415  0.018380       0.6
# 105 304 days  4.167387e+07  6455.530562  4398.338718  0.019962       0.6
# 10  325 days  3.647964e+07  6039.837575  3784.574064  0.018164       0.7
# 22  326 days  3.777531e+07  6146.162380  4143.544816  0.020989       0.6
# 34  327 days  3.309616e+07  5752.926051  3581.869386  0.016836       0.7
# 46  329 days  3.890957e+07  6237.753416  4069.502509  0.019459       0.6
# 58  330 days  3.977554e+07  6306.784866  4320.509403  0.020690       0.6
# 70  331 days  3.850361e+07  6205.127551  4158.292100  0.019899       0.7
# 82  332 days  4.235969e+07  6508.432077  4734.018144  0.022242       0.6
# 94  334 days  4.215073e+07  6492.359713  4687.867562  0.022133       0.6
# 106 335 days  4.928129e+07  7020.063687  5391.397587  0.024853       0.5
# 11  355 days  2.293877e+07  4789.443607  4019.615883  0.021311       0.5
# 23  356 days  2.458287e+07  4958.111216  4325.166305  0.023648       0.4
# 35  357 days  2.357850e+07  4855.769282  4135.888952  0.021912       0.5
# 47  359 days  2.551276e+07  5051.015397  4460.452054  0.023583       0.4
# 59  360 days  1.868912e+07  4323.091979  3772.440320  0.019581       0.5
# 71  361 days  1.780565e+07  4219.674693  3495.847307  0.018200       0.5
# 83  362 days  3.222687e+07  5676.871671  4425.396521  0.022014       0.4
# 95  364 days  3.053159e+07  5525.539664  4269.861337  0.021438       0.5
# 107 365 days  5.624352e+07  7499.567688  5682.885529  0.026656       0.4
#
# [99 rows x 6 columns]

# %%
plot_cross_validation_metric(df_cv, metric='rmse');

# %% [markdown]
# MAPE is Mean Absolute Percentage Error
#
# https://en.wikipedia.org/wiki/Mean_absolute_percentage_error

# %%
plot_cross_validation_metric(df_cv, metric='mape');

# %% [markdown]
# # Great Job!
